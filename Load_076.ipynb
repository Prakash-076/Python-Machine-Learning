# %% [markdown]
# <a href="https://colab.research.google.com/github/Prakash-076/Python-Machine-Learning/blob/main/Load_076.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv('employees details.csv')
print(d)
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 1   940761         Ms.     Brenda              S  Robinson      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail     Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com     Donald Walker        Helen Walker
# ...

# %%
#Get the column heading
df=pd.DataFrame(d)
print("Columns",df.columns)
# Out:
# Columns Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Salary'],
#       dtype='object')

# %%
#Get shape
print(df.shape)
# Out:
# (100, 11)

# %%
print("Father's Name",df["Father's Name"])
# Out:
# Father's Name 0        Donald Walker
# 1     Raymond Robinson
# 2       Scott Robinson
# 3          Jason Evans
# 4      Gregory Russell
#             ...
# 95         Carlos Hill
# 96      Richard Nelson
# 97          Ralph Ward
# 98       George Murphy
# 99        Andrew Young
# Name: Father's Name, Length: 100, dtype: object

# %%
#Extract/slice data values
print(df[5:9])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5  499687         Mr.    Patrick              F    Bailey      M
# 6  539712         Ms.      Nancy              T     Baker      F
# 7  380086        Mrs.      Carol              V    Murphy      F
# 8  477616        Hon.    Frances              B     Young      F
#
#                     E Mail  Father's Name     Mother's Name  \
# 5   patrick.bailey@aol.com   Ralph Bailey      Laura Bailey
# 6       nancy.baker@bp.com    Scott Baker        Judy Baker
# 7   carol.murphy@gmail.com  Eugene Murphy  Katherine Murphy
# 8  frances.young@gmail.com     Fred Young     Lillian Young
#
#   Mother's Maiden Name  Salary
# 5            Henderson   72305
# 6               Thomas   98189
# 7             Peterson   60918
# 8                 Diaz  121587

# %%
#Print particular person details
print("Particular Person details",df.loc[10])
# Out:
# Particular Person details Emp ID                                  231469
# Name Prefix                                Mr.
# First Name                               Ralph
# Middle Initial                               L
# Last Name                               Flores
# Gender                                       M
# E Mail                  ralph.flores@yahoo.com
# Father's Name                     Terry Flores
# Mother's Name                  Michelle Flores
# Mother's Maiden Name                     Moore
# Salary                                  118457
# Name: 10, dtype: object

# %%
#Search through salary identification
print(d.loc[d['Salary']==72305])
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 5  499687         Mr.    Patrick              F    Bailey      M
#
#                    E Mail Father's Name Mother's Name Mother's Maiden Name  \
# 5  patrick.bailey@aol.com  Ralph Bailey  Laura Bailey            Henderson
#
#    Salary
# 5   72305

# %%
#Make an average of salary
df=d['Salary']/5
print("\nMake an average of salary:\n",df)
# Out:
# Make an average of salary:
#  0     33650.2
# 1     10212.6
# 2     10031.0
# 3     36058.8
# 4     23528.4
#        ...
# 95    25954.8
# 96    31238.8
# 97    19134.6
# 98    10203.0
# 99    18730.0
# Name: Salary, Length: 100, dtype: float64

# %%
df=d['Salary']/999
print(df)
# Out:
# 0     168.419419
# 1      51.114114
# 2      50.205205
# 3     180.474474
# 4     117.759760
#          ...
# 95    129.903904
# 96    156.350350
# 97     95.768769
# 98     51.066066
# 99     93.743744
# Name: Salary, Length: 100, dtype: float64
